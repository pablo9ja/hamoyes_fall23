# %%
import numpy as np
import pandas as pd

# %%
calories = {"day1": 420,"day2": 380,"day3": 390}
myvar = pd.Series(calories, index = ["day1", "day2"])
myvar
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
myvar[0]
# Out:
# 400

# %%
calories = [400, 420, 440, 460, 480]
myvar = pd.Series(calories)
myvar
# Out:
# 0    400
# 1    420
# 2    440
# 3    460
# 4    480
# dtype: int64

# %%
calories = [400, 420, 440, 460, 480]
myvar = pd.Series(calories, index = ["day1","day2","day3","day4", "day5"])
myvar
# Out:
# day1    400
# day2    420
# day3    440
# day4    460
# day5    480
# dtype: int64

# %%
myvar.values
# Out:
# array([400, 420, 440, 460, 480], dtype=int64)

# %%
pd.DataFrame([1,2,3,4,5], columns = ["numbers"])
# Out:
#    numbers
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
arr = np.array([[1,2,3,4,5],[11,7,5,3,2]])
arr
# Out:
# array([[ 1,  2,  3,  4,  5],
#        [11,  7,  5,  3,  2]])

# %%
arrr =arr.reshape(5,2)
arrr
# Out:
# array([[ 1,  2],
#        [ 3,  4],
#        [ 5, 11],
#        [ 7,  5],
#        [ 3,  2]])

# %%
pd.DataFrame(arrr, columns = ["numbers", "reverse.prime"])
# Out:
#    numbers  reverse.prime
# 0        1              2
# 1        3              4
# 2        5             11
# 3        7              5
# 4        3              2

# %%
pd.DataFrame(arr.T, columns = ["numbers", "reverse.prime"])
# Out:
#    numbers  reverse.prime
# 0        1             11
# 1        2              7
# 2        3              5
# 3        4              3
# 4        5              2

# %%
#pd.DataFrame([1,2,3,4,5],[1,4,9,16,25], columns = ["numbers", "sq. number"])

df= pd.DataFrame({
   "numbers": [1,2,3,4,5],
"sq. number" : [1,4,9,16,25], "prime":[2,3,5,7,11]
}, columns = ["numbers", "sq. number", "prime"])
df
# Out:
#    numbers  sq. number  prime
# 0        1           1      2
# 1        2           4      3
# 2        3           9      5
# 3        4          16      7
# 4        5          25     11

# %%
df.loc[0]
# Out:
# numbers       1
# sq. number    1
# prime         2
# Name: 0, dtype: int64

# %%
import pandas as pd
df =pd.read_csv("iris_dataset.csv")
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#         target
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#              target
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isna()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                False             False              False             False
# 1                False             False              False             False
# 2                False             False              False             False
# 3                False             False              False             False
# 4                False             False              False             False
# ..                 ...               ...                ...               ...
# 145              False             False              False             False
# 146              False             False              False             False
# 147              False             False              False             False
# 148              False             False              False             False
# 149              False             False              False             False
#
#      target
# 0     False
# ...

# %%
df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
df.isna().any()
# Out:
# sepal length (cm)    False
# sepal width (cm)     False
# petal length (cm)    False
# petal width (cm)     False
# target               False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
sub_df= df.describe(include = 'all')
sub_df
# Out:
#         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count          150.000000        150.000000         150.000000
# unique                NaN               NaN                NaN
# top                   NaN               NaN                NaN
# freq                  NaN               NaN                NaN
# mean             5.843333          3.054000           3.758667
# std              0.828066          0.433594           1.764420
# min              4.300000          2.000000           1.000000
# 25%              5.100000          2.800000           1.600000
# 50%              5.800000          3.000000           4.350000
# 75%              6.400000          3.300000           5.100000
# max              7.900000          4.400000           6.900000
#
#         petal width (cm)       target
# count         150.000000          150
# unique               NaN            3
# top                  NaN  Iris-setosa
# freq                 NaN           50
# ...

# %%
#more rows are gone
sub_df.dropna()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count              150.0             150.0              150.0
#
#        petal width (cm) target
# count             150.0    150

# %%
#drop a specific column with more NA
sub_df2 = sub_df.drop("target", axis = 1)
sub_df2
# Out:
#         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count          150.000000        150.000000         150.000000
# unique                NaN               NaN                NaN
# top                   NaN               NaN                NaN
# freq                  NaN               NaN                NaN
# mean             5.843333          3.054000           3.758667
# std              0.828066          0.433594           1.764420
# min              4.300000          2.000000           1.000000
# 25%              5.100000          2.800000           1.600000
# 50%              5.800000          3.000000           4.350000
# 75%              6.400000          3.300000           5.100000
# max              7.900000          4.400000           6.900000
#
#         petal width (cm)
# count         150.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean            1.198667
# std             0.763161
# ...

# %%
# more roles is achieved by droping one column
sub_df2.dropna()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
